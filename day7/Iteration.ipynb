# %%
import pandas as pd

# %%
data={
    "Name":["Nikhil","nihal","Om"],
    "Marks":[80,90,70]
}

df=pd.DataFrame(data)

print(df)
# Out:
#      Name  Marks
# 0  Nikhil     80
# 1   nihal     90
# 2      Om     70

# %%
print(df.iloc[1])
# Out:
# Name     nihal
# Marks       90
# Name: 1, dtype: object

# %%
print(df.iloc[0:2,0:1])
# Out:
#      Name
# 0  Nikhil
# 1   nihal

# %%
#select rows unsing condtion 2
print(df[df["Marks"]>75])
# Out:
#      Name  Marks
# 0  Nikhil     80
# 1   nihal     90

# %%
#insert a row
new_row={
    "Name":"Vikas",
    "Marks":95
}

df.loc[3]=new_row

print(df)
# Out:
#      Name  Marks
# 0  Nikhil     80
# 1   nihal     90
# 2      Om     70
# 3   Vikas     95

# %%
#craeet a list from a dataframe row 
rows=df.values.tolist()

print(rows)
# Out:
# [['Nikhil', 80], ['nihal', 90], ['Om', 70], ['Vikas', 95]]
