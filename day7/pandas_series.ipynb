# %%
import pandas as pd

# %%
#Create Series from Dictionary
student = {
    "Mathdmla":90,
    "opratingsystem":85,
    "computernetwork ":95,
    "dbms":89
}

s = pd.Series(student)
print(s)
# Out:
# Mathdmla            90
# opratingsystem      85
# computernetwork     95
# dbms                89
# dtype: int64

# %%
#Create Series from list
marks = [89,87,78,55]
df = pd.Series(marks)
print(df)
#acces elements from series
print(df[0])
print(df[3])
# Out:
# 0    89
# 1    87
# 2    78
# 3    55
# dtype: int64
# 89
# 55
