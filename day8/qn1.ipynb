# %%
import pandas as pd

# %%
dates = [
    "2025-01-01",
    "2025-02-15",
    "2025-03-10"
]

series = pd.Series(dates)

print("Original Series:")
print(series)

timeseries = pd.to_datetime(series)

print("\nConverted Time Series:")
print(timeseries)
# Out:
# Original Series:
# 0    2025-01-01
# 1    2025-02-15
# 2    2025-03-10
# dtype: str
#
# Converted Time Series:
# 0   2025-01-01
# 1   2025-02-15
# 2   2025-03-10
# dtype: datetime64[us]
